# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('SP500.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series[['Open','High','Low','Close','Adj Close']].plot()
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('Bitcoin.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series[['Open','High','Low','Close','Adj Close']].plot()
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('DowJones.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series[['Open','High','Low','Close','Adj Close']].plot()
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('Nasdaq.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series[['Open','High','Low','Close','Adj Close']].plot()
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('SP500.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series['Rate'] = series['Rate']*-1
series[['Rate']].plot()
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('Bitcoin.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series['Rate'] = series['Rate']*-1
series[['Rate']].plot()
pyplot.show()

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('DowJones.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series['Rate'] = series['Rate']*-1
series[['Rate']].plot()
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-6ced9f491d40> in <module>
#       3 series = read_csv('DowJones.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
#       4 series['Rate'] = series['Rate']*-1
# ----> 5 series[['Rate']].plot()
#       6 pyplot.show()
#
# /opt/conda/lib/python3.6/site-packages/pandas/plotting/_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
# ...

# %%
from pandas import read_csv
from matplotlib import pyplot
series = read_csv('Nasdaq.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series['Rate'] = series['Rate']*-1
series[['Rate']].plot()
pyplot.show()
